# %%
import seaborn as sns
import matplotlib.pyplot as plt 
import pandas as pd
data = pd.read_csv("Social_Network_Ads (1).csv", sep = ",")

# %%
data.head(10)
# Out:
#     Age  EstimatedSalary  Purchased
# 0  19.0          19000.0        0.0
# 1  35.0          20000.0        0.0
# 2  26.0          43000.0        0.0
# 3  27.0          57000.0        0.0
# 4  19.0          76000.0        0.0
# 5  27.0          58000.0        0.0
# 6  27.0          84000.0        0.0
# 7  32.0              NaN        1.0
# 8  25.0          33000.0        0.0
# 9  35.0          65000.0        0.0

# %%
data.drop("Purchased", axis=1)
# Out:
#       Age  EstimatedSalary
# 0    19.0          19000.0
# 1    35.0          20000.0
# 2    26.0          43000.0
# 3    27.0          57000.0
# 4    19.0          76000.0
# ..    ...              ...
# 395  46.0          41000.0
# 396  51.0          23000.0
# 397  50.0          20000.0
# 398  36.0          33000.0
# 399  49.0          36000.0
#
# [400 rows x 2 columns]

# %%
data.tail(10)
# Out:
#       Age  EstimatedSalary  Purchased
# 390  48.0          33000.0        1.0
# 391  47.0          23000.0        1.0
# 392  45.0          45000.0        1.0
# 393  60.0          42000.0        1.0
# 394  39.0          59000.0        0.0
# 395  46.0          41000.0        1.0
# 396  51.0          23000.0        1.0
# 397  50.0          20000.0        1.0
# 398  36.0          33000.0        0.0
# 399  49.0          36000.0        1.0

# %%
data.isnull().sum().plot(kind='bar')
# Out:
# <Axes: >

# %%
data['Age']<30
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# Name: Age, Length: 400, dtype: bool

# %%
data[data['Age']<30]
# Out:
#       Age  EstimatedSalary  Purchased
# 0    19.0          19000.0        0.0
# 2    26.0          43000.0        0.0
# 3    27.0          57000.0        0.0
# 4    19.0          76000.0        0.0
# 5    27.0          58000.0        0.0
# ..    ...              ...        ...
# 192  29.0          43000.0        0.0
# 193  19.0          70000.0        0.0
# 194  28.0          89000.0        0.0
# 197  20.0          36000.0        0.0
# 198  26.0          80000.0        0.0
#
# [99 rows x 3 columns]

# %%
below30=data[data['Age']<30]

# %%
below30
# Out:
#       Age  EstimatedSalary  Purchased
# 0    19.0          19000.0        0.0
# 2    26.0          43000.0        0.0
# 3    27.0          57000.0        0.0
# 4    19.0          76000.0        0.0
# 5    27.0          58000.0        0.0
# ..    ...              ...        ...
# 192  29.0          43000.0        0.0
# 193  19.0          70000.0        0.0
# 194  28.0          89000.0        0.0
# 197  20.0          36000.0        0.0
# 198  26.0          80000.0        0.0
#
# [99 rows x 3 columns]

# %%
data['Age']>30
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 395     True
# 396     True
# 397     True
# 398     True
# 399     True
# Name: Age, Length: 400, dtype: bool

# %%
data[data['Age']>30]
# Out:
#       Age  EstimatedSalary  Purchased
# 1    35.0          20000.0        0.0
# 7    32.0              NaN        1.0
# 9    35.0          65000.0        0.0
# 13   32.0          18000.0        0.0
# 16   47.0          25000.0        1.0
# ..    ...              ...        ...
# 395  46.0          41000.0        1.0
# 396  51.0          23000.0        1.0
# 397  50.0          20000.0        1.0
# 398  36.0          33000.0        0.0
# 399  49.0          36000.0        1.0
#
# [288 rows x 3 columns]

# %%
above30=data[data['Age']>30]

# %%
above30
# Out:
#       Age  EstimatedSalary  Purchased
# 1    35.0          20000.0        0.0
# 7    32.0              NaN        1.0
# 9    35.0          65000.0        0.0
# 13   32.0          18000.0        0.0
# 16   47.0          25000.0        1.0
# ..    ...              ...        ...
# 395  46.0          41000.0        1.0
# 396  51.0          23000.0        1.0
# 397  50.0          20000.0        1.0
# 398  36.0          33000.0        0.0
# 399  49.0          36000.0        1.0
#
# [288 rows x 3 columns]

# %%
##purchased = data['purchase']==1, 0 is not Purchase AND 1 is Purchased
##TO Check those that did not purchased
not_purchased=data['Purchased']==0
purchased, not_purchased=data[~not_purchased], data[not_purchased]
purchased.describe()
# Out:
#               Age  EstimatedSalary  Purchased
# count  145.000000       143.000000      141.0
# mean    46.234483     85888.111888        1.0
# std      8.655453     41537.714900        0.0
# min     27.000000     20000.000000        1.0
# 25%     39.000000     41500.000000        1.0
# 50%     47.000000     90000.000000        1.0
# 75%     53.000000    122000.000000        1.0
# max     60.000000    150000.000000        1.0

# %%
##for those that purchase
not_purchased=data['Purchased']==0
purchased, not_purchased=data[~not_purchased], data[not_purchased]
not_purchased.describe()
# Out:
#               Age  EstimatedSalary  Purchased
# count  253.000000       254.000000      255.0
# mean    32.778656     60444.881890        0.0
# std      8.025654     24390.493219        0.0
# min     18.000000     15000.000000        0.0
# 25%     26.000000     44000.000000        0.0
# 50%     34.000000     61000.000000        0.0
# 75%     38.000000     77000.000000        0.0
# max     59.000000    141000.000000        0.0

# %%
data.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  398.000000       397.000000  396.000000
# mean    37.680905     69609.571788    0.356061
# std     10.492708     33887.085366    0.479439
# min     18.000000     15000.000000    0.000000
# 25%     30.000000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     87000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %%
##TO CHECK THE UNIQUE VALUES PRESENT IN THE DATA SET
data['Purchased'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
##TO CHECK THR NO OF UNIQUE VALUES (0, 1) PRESENT IN THE DATASET
data['Purchased'].nunique()
# Out:
# 2

# %%
##WHAT IS MAKING THEM NOT TO PURCHASE
##CHECK THE HIGHEST AND COMPARE TO THOSE THAT DIDNT PURCHASED
##TO COMPARE SALARIES TO KNOW REASONS FOR PURCHASE OR NON PURCHASE

not_purchased['EstimatedSalary']==max(not_purchased['EstimatedSalary'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 377    False
# 380    False
# 387    False
# 394    False
# 398    False
# Name: EstimatedSalary, Length: 255, dtype: bool

# %%
data['Age']==30
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# Name: Age, Length: 400, dtype: bool

# %%
data[data['Age']==30]
# Out:
#       Age  EstimatedSalary  Purchased
# 37   30.0          49000.0        0.0
# 43   30.0          15000.0        0.0
# 48   30.0         135000.0        1.0
# 80   30.0          80000.0        0.0
# 84   30.0          62000.0        0.0
# 91   30.0         116000.0        0.0
# 128  30.0          17000.0        0.0
# 132  30.0          87000.0        0.0
# 137  30.0         107000.0        1.0
# 143  30.0          89000.0        0.0
# 196  30.0          79000.0        0.0

# %%
compare30=data[data['Age']==30]

# %%
compare30
# Out:
#       Age  EstimatedSalary  Purchased
# 37   30.0          49000.0        0.0
# 43   30.0          15000.0        0.0
# 48   30.0         135000.0        1.0
# 80   30.0          80000.0        0.0
# 84   30.0          62000.0        0.0
# 91   30.0         116000.0        0.0
# 128  30.0          17000.0        0.0
# 132  30.0          87000.0        0.0
# 137  30.0         107000.0        1.0
# 143  30.0          89000.0        0.0
# 196  30.0          79000.0        0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              398 non-null    float64
#  1   EstimatedSalary  397 non-null    float64
#  2   Purchased        396 non-null    float64
# dtypes: float64(3)
# memory usage: 9.5 KB

# %%
data.iloc[3:9, 1:-1]
# Out:
#    EstimatedSalary
# 3          57000.0
# 4          76000.0
# 5          58000.0
# 6          84000.0
# 7              NaN
# 8          33000.0

# %%
data.shape
# Out:
# (400, 3)

# %%
subset = data[["Purchased","EstimatedSalary"]]

# %%
subset
# Out:
#      Purchased  EstimatedSalary
# 0          0.0          19000.0
# 1          0.0          20000.0
# 2          0.0          43000.0
# 3          0.0          57000.0
# 4          0.0          76000.0
# ..         ...              ...
# 395        1.0          41000.0
# 396        1.0          23000.0
# 397        1.0          20000.0
# 398        0.0          33000.0
# 399        1.0          36000.0
#
# [400 rows x 2 columns]

# %%
subset.head()
# Out:
#    Purchased  EstimatedSalary
# 0        0.0          19000.0
# 1        0.0          20000.0
# 2        0.0          43000.0
# 3        0.0          57000.0
# 4        0.0          76000.0

# %%
data.isnull().sum()
# Out:
# Age                2
# EstimatedSalary    3
# Purchased          4
# dtype: int64

# %%
data.Purchased==1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 395     True
# 396     True
# 397     True
# 398    False
# 399     True
# Name: Purchased, Length: 400, dtype: bool

# %%
data[data.Purchased==1]
# Out:
#       Age  EstimatedSalary  Purchased
# 7    32.0              NaN        1.0
# 16   47.0          25000.0        1.0
# 17   45.0          26000.0        1.0
# 18   46.0          28000.0        1.0
# 19   48.0          29000.0        1.0
# ..    ...              ...        ...
# 393  60.0          42000.0        1.0
# 395  46.0          41000.0        1.0
# 396  51.0          23000.0        1.0
# 397  50.0          20000.0        1.0
# 399  49.0          36000.0        1.0
#
# [141 rows x 3 columns]

# %%
##another way to know those that purchased
x=data['Purchased']==1
data[x]
# Out:
#       Age  EstimatedSalary  Purchased
# 7    32.0              NaN        1.0
# 16   47.0          25000.0        1.0
# 17   45.0          26000.0        1.0
# 18   46.0          28000.0        1.0
# 19   48.0          29000.0        1.0
# ..    ...              ...        ...
# 393  60.0          42000.0        1.0
# 395  46.0          41000.0        1.0
# 396  51.0          23000.0        1.0
# 397  50.0          20000.0        1.0
# 399  49.0          36000.0        1.0
#
# [141 rows x 3 columns]

# %%
##another way to know who didnt purchase
data[~x]
# Out:
#       Age  EstimatedSalary  Purchased
# 0    19.0          19000.0        0.0
# 1    35.0          20000.0        0.0
# 2    26.0          43000.0        0.0
# 3    27.0          57000.0        0.0
# 4    19.0          76000.0        0.0
# ..    ...              ...        ...
# 377  42.0          53000.0        0.0
# 380  42.0          64000.0        0.0
# 387  39.0          71000.0        0.0
# 394  39.0          59000.0        0.0
# 398  36.0          33000.0        0.0
#
# [259 rows x 3 columns]

# %%
data[data.Purchased==0]
# Out:
#       Age  EstimatedSalary  Purchased
# 0    19.0          19000.0        0.0
# 1    35.0          20000.0        0.0
# 2    26.0          43000.0        0.0
# 3    27.0          57000.0        0.0
# 4    19.0          76000.0        0.0
# ..    ...              ...        ...
# 377  42.0          53000.0        0.0
# 380  42.0          64000.0        0.0
# 387  39.0          71000.0        0.0
# 394  39.0          59000.0        0.0
# 398  36.0          33000.0        0.0
#
# [255 rows x 3 columns]

# %%
##checking for correlation of features
data.corr()
# Out:
#                       Age  EstimatedSalary  Purchased
# Age              1.000000         0.166061   0.626529
# EstimatedSalary  0.166061         1.000000   0.365690
# Purchased        0.626529         0.365690   1.000000

# %%
data["Purchased"].value_counts()
# Out:
# 0.0    255
# 1.0    141
# Name: Purchased, dtype: int64

# %%
data["Purchased"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
#DESCRIPTIVE QUESTION
# What is the age distrIbution in the dataset ?

plt.figure(figsize=(10, 4))
sns.histplot(data['Age'], bins=5, color='blue', alpha=1)
plt.title('Age Distribution')
plt.xlabel('Age') 
plt.ylabel('Frequency') 
plt.show()

# %%
plt.figure(figsize=(10, 4))
sns.histplot(data['EstimatedSalary'], bins=5, color='Red', alpha=1)
plt.title('Estimated Salary Distribution')
plt.xlabel('Estimated Salary') 
plt.ylabel('Frequency') 
plt.show()

# %%
plt.figure(figsize=(10, 4))
sns.histplot(data['Purchased'], bins=5, color='Green', alpha=1)
plt.title('Purchased Distribution')
plt.xlabel('Purchased Distribution') 
plt.ylabel('Frequency') 
plt.show()

# %% [markdown]
# # EXPLORATORY QUESTIONS

# %%
sns.boxplot(x='Purchased' , y='Age', data=data)
plt.title('Age vs Purchase')
plt.show()

# %%
# Age 17 to 52 did not make a purchase and outkiers are present in the set
#age  41 to 60 years made a purchase

# %%
sns.boxplot(x='Purchased' , y='EstimatedSalary', data=data)
plt.title('Estimated salary vs Purchased')
plt.show()

# %%
#persons earning 15000 to 77,000 did not make a purchase
#persons earning 41000 to 150,000 made a purchase

# %%
sns.kdeplot(data[data['Purchased'] == 1]['EstimatedSalary'], label='Purchased')
sns.kdeplot(data[data['Purchased'] == 0]['EstimatedSalary'], label='Not Purchased')
plt.title('Estimated Salary Distribution')
plt.xlabel('Estimated Salary')
plt.ylabel('Density') 
plt.legend()
plt.show()

# %%
#persons that purchased more earn more salary than those who didnt make a purchase

# %%
#ARE THEY ANY OUTLIERS IN THE DATA SET
sns.boxplot(data=data[['Age', 'EstimatedSalary']]) 
plt.title('Boxplot of Age and Estimated Salary') 
plt.show()

# %%
#there are no outliers in the estimated salary and age column this simply means that no value in the column is missing

# %%
#Correlation between AGE AND ESTIMATED SALARY

sns.scatterplot(x='Age', y='EstimatedSalary', data=data)
plt.title('Age vs Estimated Salary')
plt.show()

# %%
##BIVARIATE PLOT

sns.scatterplot(x= 'Age', y='Purchased', data=data)
plt.title('Purchased vs Age')
plt.show()

# %%
##theres a correlation between purchased and age of people who purchase

# %%
sns.scatterplot(x='EstimatedSalary', y='Purchased', data=data)
plt.title('Purchased vs Estimated Salary')
plt.show()

# %%
##salary has an impact on age but does not determine if someone purchased or not

# %% [markdown]
# # MULTIVARIATE

# %%
#correlation matrix using heatmap
corr_matrix=data.corr()
corr_matrix
# Out:
#                       Age  EstimatedSalary  Purchased
# Age              1.000000         0.166061   0.626529
# EstimatedSalary  0.166061         1.000000   0.365690
# Purchased        0.626529         0.365690   1.000000

# %%
import seaborn as sns
sns.heatmap(data.corr(),annot=True, cmap='viridis');

# %%
#the Age appears to have more impart in the purchased column when compared to Estimated salary with 63% positive relationship/correlatiom

# %%
#pairplot to visualize relationships between all variables
sns.pairplot(data)
plt.show()

# %%
#3D scatter plot of Age, EstimatedSalary and Purchased
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.scatter(data['Age'],data['EstimatedSalary'],data['Purchased'],c='r',marker='o')
ax.set_xlabel('Age')
ax.set_ylabel('EstimatedSalary')
ax.set_zlabel('Purchased')
plt.title('3D Scatter Plot of Age, EstimatedSalary and Purchased')
plt.show()

# %%
#Scatter plot to visualize the distribution
plt.figure(figsize=(10,5))
plt.subplot(131)
plt.scatter(data['Age'],data['EstimatedSalary'],color='blue',alpha=0.8)
plt.title('Age vs EstimatedSalary')
plt.xlabel('Age')
plt.ylabel('EstimatedSalary')
plt.subplot(132)
plt.scatter(data['Age'],data['Purchased'],color='red',alpha=0.8)
plt.title('Age vs Purchased')
plt.xlabel('Age')
plt.ylabel('Purchased')
plt.subplot(133)
plt.scatter(data['EstimatedSalary'],data['Purchased'],color='brown',alpha=0.8)
plt.title('EstimatedSalary vs Purchased')
plt.xlabel('EstimatedSalary')
plt.ylabel('Purchased')
# Out:
# Text(0, 0.5, 'Purchased')
